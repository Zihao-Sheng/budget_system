# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
import unittest
from test_suite_all import suite

runner = unittest.TextTestRunner(verbosity=2)
runner.run(suite())
# Out:
# test_add_and_sub (test_budgetfund_module.TestBudgetFundModule.test_add_and_sub) ... ok
# test_filter_status_no_records (test_budgetfund_module.TestBudgetFundModule.test_filter_status_no_records) ... ok
# test_filter_status_succeeded_and_failed (test_budgetfund_module.TestBudgetFundModule.test_filter_status_succeeded_and_failed) ...
# [setUpClass] TestBudgetFundModule
# [tearDown] Finished one TestBudgetFundModule test method
# [tearDown] Finished one TestBudgetFundModule test method
# ok
# test_get_df_empty_then_with_range (test_budgetfund_module.TestBudgetFundModule.test_get_df_empty_then_with_range) ... ok
# test_print_log_basic (test_budgetfund_module.TestBudgetFundModule.test_print_log_basic) ... ok
# test_search_log_found_and_not_found (test_budgetfund_module.TestBudgetFundModule.test_search_log_found_and_not_found) ... ok
# test_str_representation (test_budgetfund_module.TestBudgetFundModule.test_str_representation) ... ok
# test_summarize_month_no_transactions (test_budgetfund_module.TestBudgetFundModule.test_summarize_month_no_transactions) ... ok
# test_summarize_month_no_transactions_in_period (test_budgetfund_module.TestBudgetFundModule.test_summarize_month_no_transactions_in_period) ... ok
# test_summarize_month_normal_case (test_budgetfund_module.TestBudgetFundModule.test_summarize_month_normal_case) ...
# [tearDown] Finished one TestBudgetFundModule test method
# [tearDown] Finished one TestBudgetFundModule test method
# [tearDown] Finished one TestBudgetFundModule test method
# [tearDown] Finished one TestBudgetFundModule test method
# [tearDown] Finished one TestBudgetFundModule test method
# No transaction records.
# [tearDown] Finished one TestBudgetFundModule test method
# No transactions in this period.
# [tearDown] Finished one TestBudgetFundModule test method
# ok
# test_summarize_month_only_failed_transactions (test_budgetfund_module.TestBudgetFundModule.test_summarize_month_only_failed_transactions) ... ok
# test_validate_and_failed_transaction (test_budgetfund_module.TestBudgetFundModule.test_validate_and_failed_transaction) ... ok
# test_dependant_basic (test_member_type_module.TestMemberTypeModule.test_dependant_basic) ... ok
# test_guardian_job_and_income (test_member_type_module.TestMemberTypeModule.test_guardian_job_and_income) ... ok
# test_member_edit_dependant_edit_name_and_dob (test_member_type_module.TestMemberTypeModule.test_member_edit_dependant_edit_name_and_dob)
# ok选择: ...
# test_member_edit_dependant_invalid_choice (test_member_type_module.TestMemberTypeModule.test_member_edit_dependant_invalid_choice)
# ok入一个无效选项，然后再输入 3 退出， ...
# test_member_edit_guardian_edit_all_fields (test_member_type_module.TestMemberTypeModule.test_member_edit_guardian_edit_all_fields)
# okardian 菜单: ...
# test_member_edit_guardian_invalid_choice (test_member_type_module.TestMemberTypeModule.test_member_edit_guardian_invalid_choice)
# okardian 菜单下先输入无效选项，再退出， ...
# test_member_edit_unknown_type (test_member_type_module.TestMemberTypeModule.test_member_edit_unknown_type)
# ok一个 type 不是 'dependant' / 'guardian' 的对象， ...
# test_create_and_add_asset (test_asset_module.TestAssetModule.test_create_and_add_asset) ... ok
# test_update_and_delete_asset (test_asset_module.TestAssetModule.test_update_and_delete_asset) ... ok
# test_add_asset_fails_when_member_not_found (test_budget_system_module.TestBudgetSystemModule.test_add_asset_fails_when_member_not_found) ... ok
# test_add_asset_success_update_delete_summary_and_vis (test_budget_system_module.TestBudgetSystemModule.test_add_asset_success_update_delete_summary_and_vis) ...
# [tearDown] Finished one TestBudgetFundModule test method
# No succeeded transaction in this period.
# [tearDown] Finished one TestBudgetFundModule test method
# [tearDown] Finished one TestBudgetFundModule test method
# [tearDownClass] TestBudgetFundModule
#
#
# [setUpClass] MemberType tests start
# [tearDown] Completed one MemberType test
# [tearDown] Completed one MemberType test
# Current member type: dependant
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Exit editor
# Name has been updated.
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Exit editor
# Date of birth has been updated.
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Exit editor
# Exiting member editor.
# [tearDown] Completed one MemberType test
# Current member type: dependant
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Exit editor
# Invalid choice. Please try again.
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Exit editor
# Exiting member editor.
# [tearDown] Completed one MemberType test
# Current member type: guardian
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Edit job
# 4. Edit income
# 5. Exit editor
# Name has been updated.
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Edit job
# 4. Edit income
# 5. Exit editor
# Date of birth has been updated.
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Edit job
# 4. Edit income
# 5. Exit editor
# Job and income have been updated.
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Edit job
# 4. Edit income
# 5. Exit editor
# Income has been updated.
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Edit job
# 4. Edit income
# 5. Exit editor
# Exiting member editor.
# [tearDown] Completed one MemberType test
# Current member type: guardian
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Edit job
# 4. Edit income
# 5. Exit editor
# Invalid choice. Please try again.
#
# --- Member Editor ---
# 1. Edit name
# 2. Edit date of birth (DOB)
# 3. Edit job
# 4. Edit income
# 5. Exit editor
# Exiting member editor.
# [tearDown] Completed one MemberType test
# Current member type: alien
#
# --- Member Editor ---
# Unknown member type. Exiting editor.
# [tearDown] Completed one MemberType test
# [tearDownClass] MemberType tests end
#
#
# [setUpClass] Asset tests start
# Asset added: House (ID: A001R)
# [tearDown] Completed one Asset test
# Asset added: Car (ID: A002V)
# Value updated: A002V → 18000
# Asset deleted: Car (ID: A002V)
# Error: asset ID X000 not found.
# [tearDown] Completed one Asset test
# [tearDownClass] Asset tests end
#
# No member found with ID NO_SUCH. Cannot add asset.
# Asset added: House (ID: A003R)
# Value updated: A003R → 600000
# Error: asset ID NO_SUCH not found.
# ok
# test_add_get_remove_member_and_str (test_budget_system_module.TestBudgetSystemModule.test_add_get_remove_member_and_str) ... ok
# test_fund_add_sub_validate_get_df_and_summarize (test_budget_system_module.TestBudgetSystemModule.test_fund_add_sub_validate_get_df_and_summarize) ...
# Asset deleted: House (ID: A003R)
# Error: asset ID A003R not found.
# Warning: member with ID D1 already exists.
# <style type="text/css">
# #T_8ae2d_row0_col4 {
#   background-color: #d4edda;
#   color: #155724;
# }
# </style>
# <table id="T_8ae2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ae2d_level0_col0" class="col_heading level0 col0" >action</th>
#       <th id="T_8ae2d_level0_col1" class="col_heading level0 col1" >amount</th>
#       <th id="T_8ae2d_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_8ae2d_level0_col3" class="col_heading level0 col3" >balance</th>
#       <th id="T_8ae2d_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_8ae2d_level0_col5" class="col_heading level0 col5" >date</th>
#       <th id="T_8ae2d_level0_col6" class="col_heading level0 col6" >year_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ae2d_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_8ae2d_row0_col0" class="data row0 col0" >add</td>
#       <td id="T_8ae2d_row0_col1" class="data row0 col1" >300</td>
#       <td id="T_8ae2d_row0_col2" class="data row0 col2" >Income</td>
#       <td id="T_8ae2d_row0_col3" class="data row0 col3" >1450.000000</td>
#       <td id="T_8ae2d_row0_col4" class="data row0 col4" >succeeded</td>
#       <td id="T_8ae2d_row0_col5" class="data row0 col5" >2025-12-04 00:00:00</td>
#       <td id="T_8ae2d_row0_col6" class="data row0 col6" >2025-12</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_eb422_row0_col4, #T_eb422_row1_col4, #T_eb422_row2_col4, #T_eb422_row3_col4 {
#   background-color: #d4edda;
#   color: #155724;
# }
# </style>
# <table id="T_eb422">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb422_level0_col0" class="col_heading level0 col0" >action</th>
#       <th id="T_eb422_level0_col1" class="col_heading level0 col1" >amount</th>
#       <th id="T_eb422_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_eb422_level0_col3" class="col_heading level0 col3" >balance</th>
#       <th id="T_eb422_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_eb422_level0_col5" class="col_heading level0 col5" >date</th>
#       <th id="T_eb422_level0_col6" class="col_heading level0 col6" >year_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb422_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb422_row0_col0" class="data row0 col0" >add</td>
#       <td id="T_eb422_row0_col1" class="data row0 col1" >200</td>
#       <td id="T_eb422_row0_col2" class="data row0 col2" >Salary</td>
#       <td id="T_eb422_row0_col3" class="data row0 col3" >1200.000000</td>
#       <td id="T_eb422_row0_col4" class="data row0 col4" >succeeded</td>
#       <td id="T_eb422_row0_col5" class="data row0 col5" >2025-12-04 00:00:00</td>
#       <td id="T_eb422_row0_col6" class="data row0 col6" >2025-12</td>
#     </tr>
#     <tr>
#       <th id="T_eb422_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb422_row1_col0" class="data row1 col0" >sub</td>
#       <td id="T_eb422_row1_col1" class="data row1 col1" >50</td>
#       <td id="T_eb422_row1_col2" class="data row1 col2" >Snacks</td>
#       <td id="T_eb422_row1_col3" class="data row1 col3" >1150.000000</td>
#       <td id="T_eb422_row1_col4" class="data row1 col4" >succeeded</td>
#       <td id="T_eb422_row1_col5" class="data row1 col5" >2025-12-04 00:00:00</td>
#       <td id="T_eb422_row1_col6" class="data row1 col6" >2025-12</td>
#     </tr>
#     <tr>
#       <th id="T_eb422_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb422_row2_col0" class="data row2 col0" >add</td>
#       <td id="T_eb422_row2_col1" class="data row2 col1" >300</td>
#       <td id="T_eb422_row2_col2" class="data row2 col2" >Income</td>
#       <td id="T_eb422_row2_col3" class="data row2 col3" >1450.000000</td>
#       <td id="T_eb422_row2_col4" class="data row2 col4" >succeeded</td>
#       <td id="T_eb422_row2_col5" class="data row2 col5" >2025-12-04 00:00:00</td>
#       <td id="T_eb422_row2_col6" class="data row2 col6" >2025-12</td>
#     </tr>
#     <tr>
#       <th id="T_eb422_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb422_row3_col0" class="data row3 col0" >sub</td>
#       <td id="T_eb422_row3_col1" class="data row3 col1" >80</td>
#       <td id="T_eb422_row3_col2" class="data row3 col2" >Groceries</td>
#       <td id="T_eb422_row3_col3" class="data row3 col3" >1370.000000</td>
#       <td id="T_eb422_row3_col4" class="data row3 col4" >succeeded</td>
#       <td id="T_eb422_row3_col5" class="data row3 col5" >2025-12-04 00:00:00</td>
#       <td id="T_eb422_row3_col6" class="data row3 col6" >2025-12</td>
#     </tr>
#   </tbody>
# </table>
# ok
# test_fund_editor_add_sub_and_back (test_budget_system_module.TestBudgetSystemModule.test_fund_editor_add_sub_and_back) ... ok
# test_initialization_first_time_setup (test_budget_system_module.TestBudgetSystemModule.test_initialization_first_time_setup) ... ok
# test_initialization_with_system_already_provided (test_budget_system_module.TestBudgetSystemModule.test_initialization_with_system_already_provided) ... ok
# test_list_member_with_and_without_members (test_budget_system_module.TestBudgetSystemModule.test_list_member_with_and_without_members) ... ok
# test_log_viewer_print_search_filter_summary_and_exit (test_budget_system_module.TestBudgetSystemModule.test_log_viewer_print_search_filter_summary_and_exit) ...
# No transactions in this period.
# No transactions in this period.
# No transactions in this period.
# === Fund Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1000.0
# ------------------------------
#
# Options:
# 1. Add Fund
# 2. Sub Fund
# 3. Back to main menu
# ------------------------------
# === Add Fund ===
# === Fund Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1100.0
# ------------------------------
#
# Options:
# 1. Add Fund
# 2. Sub Fund
# 3. Back to main menu
# ------------------------------
# === Sub Fund ===
# === Fund Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1070.0
# ------------------------------
#
# Options:
# 1. Add Fund
# 2. Sub Fund
# 3. Back to main menu
# ------------------------------
# Welcome to the Family Budget System
# Please follow the instruction to Initialize the system
# No members in the system.
# Child (ID: D1, Dependant)
# === Fund Log Viewer ===
# Household: Test Family
# ------------------------------
# 1. Print full fund log
# 2. Search fund log by keyword
# 3. Filter fund log by status
# 4. Monthly / period summary
# 5. Back to main menu
# ------------------------------
# === Print Fund Log ===
# You can enter a date range to filter the log.
# Leave blank to use full range.
# <style type="text/css">
# #T_5cbb6_row0_col4, #T_5cbb6_row1_col4 {
#   background-color: #d4edda;
#   color: #155724;
# }
# </style>
# <table id="T_5cbb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cbb6_level0_col0" class="col_heading level0 col0" >action</th>
#       <th id="T_5cbb6_level0_col1" class="col_heading level0 col1" >amount</th>
#       <th id="T_5cbb6_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_5cbb6_level0_col3" class="col_heading level0 col3" >balance</th>
#       <th id="T_5cbb6_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_5cbb6_level0_col5" class="col_heading level0 col5" >date</th>
#       <th id="T_5cbb6_level0_col6" class="col_heading level0 col6" >year_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cbb6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cbb6_row0_col0" class="data row0 col0" >add</td>
#       <td id="T_5cbb6_row0_col1" class="data row0 col1" >200</td>
#       <td id="T_5cbb6_row0_col2" class="data row0 col2" >Income</td>
#       <td id="T_5cbb6_row0_col3" class="data row0 col3" >1200.000000</td>
#       <td id="T_5cbb6_row0_col4" class="data row0 col4" >succeeded</td>
#       <td id="T_5cbb6_row0_col5" class="data row0 col5" >2025-12-04 00:00:00</td>
#       <td id="T_5cbb6_row0_col6" class="data row0 col6" >2025-12</td>
#     </tr>
#     <tr>
#       <th id="T_5cbb6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5cbb6_row1_col0" class="data row1 col0" >sub</td>
#       <td id="T_5cbb6_row1_col1" class="data row1 col1" >50</td>
#       <td id="T_5cbb6_row1_col2" class="data row1 col2" >Food</td>
#       <td id="T_5cbb6_row1_col3" class="data row1 col3" >1150.000000</td>
#       <td id="T_5cbb6_row1_col4" class="data row1 col4" >succeeded</td>
#       <td id="T_5cbb6_row1_col5" class="data row1 col5" >2025-12-04 00:00:00</td>
#       <td id="T_5cbb6_row1_col6" class="data row1 col6" >2025-12</td>
#     </tr>
#   </tbody>
# </table>
# === Fund Log Viewer ===
# Household: Test Family
# ------------------------------
# 1. Print full fund log
# 2. Search fund log by keyword
# 3. Filter fund log by status
# 4. Monthly / period summary
# 5. Back to main menu
# ------------------------------
# === Search Fund Log ===
# <style type="text/css">
# #T_99577_row0_col4 {
#   background-color: #d4edda;
#   color: #155724;
# }
# </style>
# <table id="T_99577">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99577_level0_col0" class="col_heading level0 col0" >action</th>
#       <th id="T_99577_level0_col1" class="col_heading level0 col1" >amount</th>
#       <th id="T_99577_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_99577_level0_col3" class="col_heading level0 col3" >balance</th>
#       <th id="T_99577_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_99577_level0_col5" class="col_heading level0 col5" >date</th>
#       <th id="T_99577_level0_col6" class="col_heading level0 col6" >year_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99577_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99577_row0_col0" class="data row0 col0" >add</td>
#       <td id="T_99577_row0_col1" class="data row0 col1" >200</td>
#       <td id="T_99577_row0_col2" class="data row0 col2" >Income</td>
#       <td id="T_99577_row0_col3" class="data row0 col3" >1200.000000</td>
#       <td id="T_99577_row0_col4" class="data row0 col4" >succeeded</td>
#       <td id="T_99577_row0_col5" class="data row0 col5" >2025-12-04 00:00:00</td>
#       <td id="T_99577_row0_col6" class="data row0 col6" >2025-12</td>
#     </tr>
#   </tbody>
# </table>
# === Fund Log Viewer ===
# Household: Test Family
# ------------------------------
# 1. Print full fund log
# 2. Search fund log by keyword
# 3. Filter fund log by status
# 4. Monthly / period summary
# 5. Back to main menu
# ------------------------------
# === Filter Fund Log by Status ===
# Do you want to see:
# 1. Succeeded records
# 2. Failed records
# <style type="text/css">
# #T_76a5b_row0_col4, #T_76a5b_row1_col4 {
#   background-color: #d4edda;
#   color: #155724;
# }
# </style>
# <table id="T_76a5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76a5b_level0_col0" class="col_heading level0 col0" >action</th>
#       <th id="T_76a5b_level0_col1" class="col_heading level0 col1" >amount</th>
#       <th id="T_76a5b_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_76a5b_level0_col3" class="col_heading level0 col3" >balance</th>
#       <th id="T_76a5b_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_76a5b_level0_col5" class="col_heading level0 col5" >date</th>
#       <th id="T_76a5b_level0_col6" class="col_heading level0 col6" >year_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76a5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76a5b_row0_col0" class="data row0 col0" >add</td>
#       <td id="T_76a5b_row0_col1" class="data row0 col1" >200</td>
#       <td id="T_76a5b_row0_col2" class="data row0 col2" >Income</td>
#       <td id="T_76a5b_row0_col3" class="data row0 col3" >1200.000000</td>
#       <td id="T_76a5b_row0_col4" class="data row0 col4" >succeeded</td>
#       <td id="T_76a5b_row0_col5" class="data row0 col5" >2025-12-04 00:00:00</td>
#       <td id="T_76a5b_row0_col6" class="data row0 col6" >2025-12</td>
#     </tr>
#     <tr>
#       <th id="T_76a5b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76a5b_row1_col0" class="data row1 col0" >sub</td>
#       <td id="T_76a5b_row1_col1" class="data row1 col1" >50</td>
#       <td id="T_76a5b_row1_col2" class="data row1 col2" >Food</td>
#       <td id="T_76a5b_row1_col3" class="data row1 col3" >1150.000000</td>
#       <td id="T_76a5b_row1_col4" class="data row1 col4" >succeeded</td>
#       <td id="T_76a5b_row1_col5" class="data row1 col5" >2025-12-04 00:00:00</td>
#       <td id="T_76a5b_row1_col6" class="data row1 col6" >2025-12</td>
#     </tr>
#   </tbody>
# </table>
# ok
# test_main_menu_all_options (test_budget_system_module.TestBudgetSystemModule.test_main_menu_all_options) ... ok
# test_main_menu_quick_quit (test_budget_system_module.TestBudgetSystemModule.test_main_menu_quick_quit) ... ok
# test_member_editor_add_delete_upgrade_edit_and_exit (test_budget_system_module.TestBudgetSystemModule.test_member_editor_add_delete_upgrade_edit_and_exit) ...
# === Fund Log Viewer ===
# Household: Test Family
# ------------------------------
# 1. Print full fund log
# 2. Search fund log by keyword
# 3. Filter fund log by status
# 4. Monthly / period summary
# 5. Back to main menu
# ------------------------------
# === Fund Summary ===
# Please enter the summary period.
# For monthly summary, you can use year-month format like 2025-05.
# No transactions in this period.
# === Fund Log Viewer ===
# Household: Test Family
# ------------------------------
# 1. Print full fund log
# 2. Search fund log by keyword
# 3. Filter fund log by status
# 4. Monthly / period summary
# 5. Back to main menu
# ------------------------------
# ===== Family Budget System =====
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1000.0
# --------------------------------
# 1. Member editor
# 2. Fund / Expense editor
# 3. Transaction log
# 4. Property Manager
# 5. Quit
# --------------------------------
# ===== Family Budget System =====
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1000.0
# --------------------------------
# 1. Member editor
# 2. Fund / Expense editor
# 3. Transaction log
# 4. Property Manager
# 5. Quit
# --------------------------------
# ===== Family Budget System =====
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1000.0
# --------------------------------
# 1. Member editor
# 2. Fund / Expense editor
# 3. Transaction log
# 4. Property Manager
# 5. Quit
# --------------------------------
# ===== Family Budget System =====
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1000.0
# --------------------------------
# 1. Member editor
# 2. Fund / Expense editor
# 3. Transaction log
# 4. Property Manager
# 5. Quit
# --------------------------------
# ===== Family Budget System =====
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1000.0
# --------------------------------
# 1. Member editor
# 2. Fund / Expense editor
# 3. Transaction log
# 4. Property Manager
# 5. Quit
# --------------------------------
# Thank you for using the system. Goodbye!
# ===== Family Budget System =====
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1000.0
# --------------------------------
# 1. Member editor
# 2. Fund / Expense editor
# 3. Transaction log
# 4. Property Manager
# 5. Quit
# --------------------------------
# Thank you for using the system. Goodbye!
# === Member Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 0
# Current Fund: 1000.0
# ------------------------------
# Current members:
#   (No members yet)
#
# Options:
# 1. List members
# 2. Add member
# 3. Delete member
# 4. Upgrade member (dependant → guardian)
# 5. Edit member by ID
# 6. Back to main menu
# ------------------------------
# === Add Member ===
#
# Member successfully added.
# === Member Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 1
# Current Fund: 1000.0
# ------------------------------
# Current members:
#   New Guardian (ID: G99, Guardian, Income: 80000.0, Job: Engineer)
#
# Options:
# 1. List members
# 2. Add member
# 3. Delete member
# 4. Upgrade member (dependant → guardian)
# 5. Edit member by ID
# 6. Back to main menu
# ------------------------------
# === Delete Member ===
# No member found with ID NO_SUCH.
# === Member Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 1
# Current Fund: 1000.0
# ------------------------------
# Current members:
#   New Guardian (ID: G99, Guardian, Income: 80000.0, Job: Engineer)
#
# Options:
# 1. List members
# 2. Add member
# 3. Delete member
# 4. Upgrade member (dependant → guardian)
# 5. Edit member by ID
# 6. Back to main menu
# ------------------------------
# === Upgrade Member (dependant → guardian) ===
# Member with ID G99 has been upgraded to guardian.
# === Member Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 1
# Current Fund: 1000.0
# ------------------------------
# Current members:
#   New Guardian (ID: G99, Guardian, Income: 80000.0, Job: Engineer)
#
# Options:
# 1. List members
# 2. Add member
# 3. Delete member
# 4. Upgrade member (dependant → guardian)
# 5. Edit member by ID
# 6. Back to main menu
# ------------------------------
# === Edit Member by ID ===
# === Member Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 1
# Current Fund: 1000.0
# ------------------------------
# Current members:
#   New Guardian (ID: G99, Guardian, Income: 80000.0, Job: Engineer)
#
# Options:
# 1. List members
# 2. Add member
# 3. Delete member
# 4. Upgrade member (dependant → guardian)
# 5. Edit member by ID
# 6. Back to main menu
# ------------------------------
# ok
# test_member_editor_list_and_exit (test_budget_system_module.TestBudgetSystemModule.test_member_editor_list_and_exit) ... ok
# test_property_editor_add_asset_via_cli_and_exit (test_budget_system_module.TestBudgetSystemModule.test_property_editor_add_asset_via_cli_and_exit) ... ok
# test_property_editor_delete_and_reports_and_exit (test_budget_system_module.TestBudgetSystemModule.test_property_editor_delete_and_reports_and_exit) ... ok
# test_property_editor_edit_asset_flow (test_budget_system_module.TestBudgetSystemModule.test_property_editor_edit_asset_flow) ... ok
# test_upgrade_member_not_found_and_already_guardian (test_budget_system_module.TestBudgetSystemModule.test_upgrade_member_not_found_and_already_guardian) ... ok
# test_upgrade_member_success (test_budget_system_module.TestBudgetSystemModule.test_upgrade_member_success) ... ok
#
# ----------------------------------------------------------------------
# Ran 39 tests in 2.180s
#
# OK
# === Member Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 1
# Current Fund: 1000.0
# ------------------------------
# Current members:
#   Child (ID: D1, Dependant)
#
# Options:
# 1. List members
# 2. Add member
# 3. Delete member
# 4. Upgrade member (dependant → guardian)
# 5. Edit member by ID
# 6. Back to main menu
# ------------------------------
# === Member List ===
# Child (ID: D1, Dependant)
# === Member Editor ===
# Budget System for Test Family
# Address: 123 Test St
# Members: 1
# Current Fund: 1000.0
# ------------------------------
# Current members:
#   Child (ID: D1, Dependant)
#
# Options:
# 1. List members
# 2. Add member
# 3. Delete member
# 4. Upgrade member (dependant → guardian)
# 5. Edit member by ID
# 6. Back to main menu
# ------------------------------
# === Property / Asset Editor ===
# Household: Test Family
# Total assets: 0
# ------------------------------
# (No assets yet.)
# ------------------------------
# 1. Add new asset
# 2. Edit existing asset
# 3. Delete asset
# 4. Reports & analysis
# 5. Back to main menu
# ------------------------------
# === Add New Asset ===
# Available asset types:
# 1. Real Estate
# 2. Vehicle
# 3. Investment
# 4. Other
# Current members:
# Parent (ID: G1, Guardian, Income: 80000, Job: Engineer)
#
# Select owner:
# 1. Parent (ID: G1)
# Asset added: Car (ID: A004R)
# === Property / Asset Editor ===
# Household: Test Family
# Total assets: 1
# ------------------------------
# Asset ID Name        Type Owner Value_Display
#    A004R  Car Real Estate    G1    $20,000.00
# ------------------------------
# 1. Add new asset
# 2. Edit existing asset
# 3. Delete asset
# 4. Reports & analysis
# 5. Back to main menu
# ------------------------------
# Asset added: Car (ID: A005V)
# === Property / Asset Editor ===
# Household: Test Family
# Total assets: 1
# ------------------------------
# Asset ID Name    Type Owner Value_Display
#    A005V  Car Vehicle    G1    $20,000.00
# ------------------------------
# 1. Add new asset
# 2. Edit existing asset
# 3. Delete asset
# 4. Reports & analysis
# 5. Back to main menu
# ------------------------------
# === Delete Asset ===
# Asset deleted: Car (ID: A005V)
# === Property / Asset Editor ===
# Household: Test Family
# Total assets: 0
# ------------------------------
# (No assets yet.)
# ------------------------------
# 1. Add new asset
# 2. Edit existing asset
# 3. Delete asset
# 4. Reports & analysis
# 5. Back to main menu
# ------------------------------
# === Asset Reports & Analysis ===
# 1. List all assets
# 2. Asset summary
# 3. Search assets
# 4. Visualization data
# 5. Back
# ------------------------------
# === Asset List ===
# No assets in the system.
# === Asset Reports & Analysis ===
# 1. List all assets
# 2. Asset summary
# 3. Search assets
# 4. Visualization data
# 5. Back
# ------------------------------
# === Asset Summary ===
# Total asset value: $0.00
#
# Summary by Type and Owner:
# No data.
# === Asset Reports & Analysis ===
# 1. List all assets
# 2. Asset summary
# 3. Search assets
# 4. Visualization data
# 5. Back
# ------------------------------
# === Search Assets ===
# No matching assets found.
# === Asset Reports & Analysis ===
# 1. List all assets
# 2. Asset summary
# 3. Search assets
# 4. Visualization data
# 5. Back
# ------------------------------
# === Asset Visualization Data ===
# Group by:
# 1. Type
# 2. Owner
# No asset data to visualize.
# No data available.
# === Asset Reports & Analysis ===
# 1. List all assets
# 2. Asset summary
# 3. Search assets
# 4. Visualization data
# 5. Back
# ------------------------------
# === Property / Asset Editor ===
# Household: Test Family
# Total assets: 0
# ------------------------------
# (No assets yet.)
# ------------------------------
# 1. Add new asset
# 2. Edit existing asset
# 3. Delete asset
# 4. Reports & analysis
# 5. Back to main menu
# ------------------------------
# Asset added: Car (ID: A006V)
# === Property / Asset Editor ===
# Household: Test Family
# Total assets: 1
# ------------------------------
# Asset ID Name    Type Owner Value_Display
#    A006V  Car Vehicle    G1    $20,000.00
# ------------------------------
# 1. Add new asset
# 2. Edit existing asset
# 3. Delete asset
# 4. Reports & analysis
# 5. Back to main menu
# ------------------------------
# === Edit Asset ===
# === Edit Asset ===
# Asset(ID=A006V, Name='Car', Type='Vehicle',
# ------------------------------
# 1. Edit name
# 2. Edit current value
# 3. Edit type
# 4. Edit owner
# 5. Back
# ------------------------------
# Name updated.
# === Edit Asset ===
# Asset(ID=A006V, Name='Renamed Asset', Type='Vehicle',
# ------------------------------
# 1. Edit name
# 2. Edit current value
# 3. Edit type
# 4. Edit owner
# 5. Back
# ------------------------------
# Value updated: A006V → 9999.0
# === Edit Asset ===
# Asset(ID=A006V, Name='Renamed Asset', Type='Vehicle',
# ------------------------------
# 1. Edit name
# 2. Edit current value
# 3. Edit type
# 4. Edit owner
# 5. Back
# ------------------------------
# Available asset types:
# 1. Real Estate
# 2. Vehicle
# 3. Investment
# 4. Other
# Type updated.
# === Edit Asset ===
# Asset(ID=A006V, Name='Renamed Asset', Type='Real Estate',
# ------------------------------
# 1. Edit name
# 2. Edit current value
# 3. Edit type
# 4. Edit owner
# 5. Back
# ------------------------------
# Current members:
# Parent (ID: G1, Guardian, Income: 80000, Job: Engineer)
#
# Select owner:
# 1. Parent (ID: G1)
# Owner updated.
# === Edit Asset ===
# Asset(ID=A006V, Name='Renamed Asset', Type='Real Estate',
# ------------------------------
# 1. Edit name
# 2. Edit current value
# 3. Edit type
# 4. Edit owner
# 5. Back
# ------------------------------
# === Property / Asset Editor ===
# Household: Test Family
# Total assets: 1
# ------------------------------
# Asset ID          Name        Type Owner Value_Display
#    A006V Renamed Asset Real Estate    G1     $9,999.00
# ------------------------------
# 1. Add new asset
# 2. Edit existing asset
# 3. Delete asset
# 4. Reports & analysis
# 5. Back to main menu
# ------------------------------
# No member found
# Member already a guardian
# <unittest.runner.TextTestResult run=39 errors=0 failures=0>
